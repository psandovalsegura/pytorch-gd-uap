# %%
from plot import *
from analyze import *
uap = get_pt_uap('463159_vgg16_no_data_iter=2023_val=voc2012_fr=963.npy') #final
plot_uap(uap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# L-inf Norm: 0.03921568766236305

# %%
uap = get_pt_uap('vgg19_no_data_iter=2572_val=voc2012_fr=941.npy') #final
plot_uap(uap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# L-inf Norm: 0.03921568766236305

# %%
uap = get_pt_uap('463456_googlenet_no_data_iter=3501_val=voc2012_fr=678.npy') # final
plot_uap(uap)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# L-inf Norm: 0.03921568766236305

# %%
plot_uap(get_pt_uap('463458_resnet50_no_data_iter=2924_val=voc2012_fr=688.npy')) #final
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# L-inf Norm: 0.03921568766236305

# %%
plot_uap(get_pt_uap('463459_resnet152_no_data_iter=3443_val=voc2012_fr=626.npy')) #final
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# L-inf Norm: 0.03921568766236305
